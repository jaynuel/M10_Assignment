# %%
####
#Author: Jesus Olivera
#version 1.0
##

###Load libraries
import awscli
import selenium
import boto3
import pandas as pd
import time

from selenium import webdriver


####SCRAPE THE WEBSITE######
###call the webdriver
browser = webdriver.Chrome("C:\Windows/chromedriver.exe")

#Path that needs to be accessed by webdriver
browser.get('https://www.charitiesnys.com/RegistrySearch/search_charities.jsp')

#identify xpath of location to select element
inputElement = browser.find_element_by_xpath("/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[2]/td[2]/input[1]")
inputElement.send_keys('0')

inputElement1 = browser.find_element_by_xpath("/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[10]/td/input[1]").click()

#identify the table to scrape
table = browser.find_element_by_css_selector('table.Bordered')

print(table)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="824c1a8680801ce2d89710f13dd3dd0f", element="0.30956027063101965-1")>

# %%
#####CREATE DATE FRAME#####
#create empty dataframe
df =[]

# Number of pages
num_pages = [1,2,3,4,5,6,7]

# For Loop through all pages
for x in num_pages:
    table = browser.find_element_by_css_selector('table.Bordered')
    
# To dataframe
    
    for row in table.find_elements_by_css_selector('tr'):
        cols = df.append([cell.text for cell in row.find_elements_by_css_selector('td')])
    
# Pagination
    p = browser.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr/td[3]/div/div/span[2]/a['+str(x)+']').click()

#update dataframe with header 
df = pd.DataFrame(df, columns = ["Organization Name", "NY Reg #", "EIN" ,"Registrant Type","City","State"])
# display(df) #let's have a look at the data before creating the CSV file and loading it into s3

# Removing row with "None" values and re-indexing the dataframe
updated_df = pd.DataFrame(df).dropna().reset_index().drop(['index'], axis=1) 


pd.set_option('display.max_rows', None)

updated_df
# Out:
#                                      Organization Name  NY Reg #        EIN  \
# 0                                   "Studio 5404" Inc.  44-39-58  463180470
# 1                        "THEY ARE HAITIAN" FUND, INC.  20-63-46  300170128
# 2    (ASMA) American Syrian Multicultural Associati...  42-84-63  273130182
# 3                                    #HicksStrong Inc.  48-10-48  842612081
# 4                                 #WalkAway Foundation  47-15-80  832820906
# 5                                  04/11 10:17 PM test  47-13-95  206256427
# 6                                  1/20/21 Action Fund  46-99-13  832210730
# 7                              10/40 Connections, Inc.  45-70-15  621825230
# 8                               1000 Feet Project, Inc  45-00-14  473820859
# 9                            1000 Islands Hose Haulers  45-38-38  454570241
# 10                               1004 Foundation, Inc.  45-00-13  463110658
# 11   100 BLACK MEN OF LONG ISLAND DEVELOPMENT GROUP...  20-08-47  113617702
# 12                             100 BLACKS WHO CARE INC  06-42-84  311628801
# 13       100 BLACK WOMEN OF LONG ISLAND FOUNDATION INC  05-79-45  113101805
# 14                                    100Cameras, Inc.  43-16-19  264692506
# 15                             100 CLUB OF BUFFALO INC  03-01-89  160957291
# 16   100 E. 182ND Street Housing Development Fund C...  43-46-29  133881096
# 17                              100 GROTON PARKWAY INC  15-51-96  222661001
# 18                          100 Lives Foundation, Inc.  45-60-79  364808338
# 19                       100 Mile Man Foundation, Inc.  20-23-17  200565515
# 20                                    100 WHO CARE INC  06-65-86  134068307
# 21              100 Women in Finance Association, Inc.  20-90-57  571174550
# 22                   1026 Foundation Corporation (The)  46-42-92  823378707
# 33              NFP         CLIFTON PARK    NY
# 34              NFP             CARLSBAD    CA
# 35              NFP               ALBANY    NY
# 36              NFP        SAN FRANCISCO    CA
# 37              NFP               HIXSON    TN
# 38              NFP             NEW YORK    NY
# 39              NFP             CARTHAGE    NY
# 40              NFP     LONG ISLAND CITY    NY
# 41              NFP            HEMPSTEAD    NY
# 42              NFP             BROOKLYN    NY
# 43              NFP          GARDEN CITY    NY
# 44              NFP             NEW YORK    NY
# 45              NFP             NEW YORK    NY
# 46              NFP              BUFFALO    NY
# 47              NFP             NEW YORK    NY
# 48              NFP             BROOKLYN    NY
# 49              NFP             BROOKLYN    NY
# 50              NFP           LACKAWANNA    NY
# 51              NFP             NEW YORK    NY
# 52              NFP             FLORENCE    NJ
# 53              NFP             BROOKLYN    NY
# 54              NFP              FAIRFAX    VA
# 55              NFP            LEVITTOWN    NY
# 56              NFP              BUFFALO    NY
# 57              NFP             BROOKLYN    NY
# 58              NFP             NEW YORK    NY
# 59              NFP             BROOKLYN    NY
# 60              NFP              BUFFALO    NY
# 61              NFP                BRONX    NY
# 62              NFP            ROCHESTER    NY
# 63              NFP           WASHINGTON    DC
# 64              NFP             NEW YORK    NY
# 65              NFP     LONG ISLAND CITY    NY
# 66              NFP             NEW YORK    NY
# 67              NFP  SPRINGFIELD GARDENS    NY
# 68              NFP            MT. KISCO    NY
# 69              NFP              JAMAICA    NY
# 70              NFP   COLD SPRING HARBOR    NY
# 71              NFP                BRONX    NY
# 72              NFP          WESTHAMPTON    NY
# 73              NFP                BRONX    NY
# 74              NFP             NEW YORK    NY
# 75              NFP             NEW YORK    NY
# 76              NFP              BUFFALO    NY
# 77              NFP             NEW YORK    NY
# 78              NFP             BROOKLYN    NY
# 79              NFP             BROOKLYN    NY
# 80              NFP           LACKAWANNA    NY
# 81              NFP             NEW YORK    NY
# 82              NFP             FLORENCE    NJ
# 83              NFP             BROOKLYN    NY
# 84              NFP              FAIRFAX    VA
# 85              NFP            LEVITTOWN    NY
# 86              NFP              BUFFALO    NY
# 87              NFP             BROOKLYN    NY
# 88              NFP             NEW YORK    NY
# 89              NFP             BROOKLYN    NY
# 90              NFP           GREENVILLE    SC
# 91              NFP             NEW YORK    NY
# 92              NFP                GERRY    NY
# 93              NFP             NEW YORK    NY
# 94              NFP          FULTONVILLE    NY
# 95              NFP             BROOKLYN    NY
# 96              NFP          KEW GARDENS    NY
# 97              NFP             NEW YORK    NY
# 98              NFP                HOMER    NY
# 99              NFP                PROVO    UT
# 100             NFP                BRONX    NY
# 101             NFP              CHICAGO    IL
# 102             NFP                BRONX    NY
# 103             NFP             BROOKLYN    NY
# 104             NFP             WOODMERE    NY

# %%
###LOAD THE FILE INTO S3####
# prepare csv file name   
pathname = 's3:/yubucket1/'
filename= 'charities_bureau_scrape_Part2' #name of your group
datetime = time.strftime("%Y%m%d%H%M%S") #timestamp
filenames3 = "%s%s%s.csv"%(pathname,filename,datetime) #name of the filepath and csv file

#load file into s3. Pandas actually leverages boto to connect to s3 and can push the file directly into an s3 bucket
updated_df.to_csv(filenames3, header=True, line_terminator='\n') 

#print success message
print("Successfull uploaded file to location:"+str(filenames3))
# Out:
# Successfull uploaded file to location:s3:/yubucket1/charities_bureau_scrape_Part220210329160359.csv
